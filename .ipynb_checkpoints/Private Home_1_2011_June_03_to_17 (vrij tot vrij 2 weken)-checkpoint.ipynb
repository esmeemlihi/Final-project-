# %%
'''
Measurement site: 
Single family housing

number of people per house: 
3 adult people;

Sampling period: 
5 minutes
Start: 03-June-2011; 
End: 18- June -2011


• Número de divisões da casa: 
3 quartos, 3 casas de banho, 
1 sala de estar, 1 cozinha, 
1 lavandaria, 1 hall de entrada e corredor;

• Major Charges: 1 washer / dryer, 
1 dishwasher, 1 electric hob, 
1 electric oven , 
1 fridge, 
1 microwave, 
1 extractor, 
1 vacuum cleaner, 
1 hair dryer, 
3 TVs, 
1 LCD, 
2 laptop, 
1 router, 
2 electric heaters.

Measurement instruments: 
Chauvin Arnoux 8335
Installation single-phase 5.75 kVA


'''

# %%
# imports 

import pandas as pd
import numpy as np 
import re 
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
from datetime import datetime

# %%
# general plot settings 
sns.set(rc={'figure.figsize':(16,5)})
sns.set_style('ticks')

# %%
# functions

# makes a date time 'grouped' series 
def make_date_time (df):
    df['DateTime'] = pd.to_datetime(df.Date + ' ' + df.Time)
    df['hour'] = df.DateTime.dt.hour
    df['day'] = df.DateTime.dt.day_name()
    df['5_min'] = df.DateTime.dt.minute
    return df 

# transformes '00:01:15' 5 min string to 000115 int to preserve the hour factor  
def make_min_string(Time_string):
    a = re.findall('[^:]+',Time_string)
    b = ''.join(a)
    return int(b)

# makes an new 5_min column with hour indication 
def make_5_min_int_column(df):
    time_list = list(df.Time)
    time_list_2 = [make_min_string(time_list[i]) for i in range(len(time_list))]
    df['5_in_sec'] = time_list_2
    return df

# make the hour column in the same sec scale as the min column 
def tranform_hour_in_sec_scale (df):
    hour_list = [list(df.hour)[i]*10000 for i in range(len(list(df.hour)))]
    df['hour_in_sec'] = hour_list
    return df
    
# selects the relevenat columns
def select_relavant_columns(df):
    return df[['DateTime','day', 'hour_in_sec','5_in_sec', 'W1','Wh1','Frequency']]

# strandformes the relevant columns into numeric columns                
def make_numeric (df):
    df[['Frequency','W1','Wh1']] = df[['Frequency','W1','Wh1']].apply(pd.to_numeric,errors='coerce')
    return df 
              
# alle functions together in the right order                
def make_cleaned_df (dataframe):
    df_1 = make_date_time(dataframe)
    df_2 = make_5_min_int_column(df_1)
    df_3 = tranform_hour_in_sec_scale (df_2)
    df_4 = select_relavant_columns(df_3)
    df_5 = make_numeric(df_4)
    return df_5

# creating a weekend data frame
def make_weekend(df):
    df = df.loc[(df['day']=='Saturday') | (df['day']=='Sunday')]
    return df

# creating a week data frame
def make_week(df):
    df = df.loc[~((df['day']=='Saturday') | (df['day']=='Sunday'))]
    return df

# %%
# Private Home_1_2011_June_03_to_17.xls

Home_1_selecting = pd.read_excel("data/Private Home_1_2011_June_03_to_17.xls", sheet_name='Trend', header=6)[2:]
Home_1_2011_June_03_to_17 = make_cleaned_df(Home_1_selecting)

Total_average_min = sns.lineplot(x='5_in_sec', y="W1", data=Home_1_2011_June_03_to_17) 
Total_average_hour = sns.lineplot(x='hour_in_sec', y="W1", data=Home_1_2011_June_03_to_17)

Home_1_2011_June_03_to_17.head()
# Out:
#              DateTime     day  hour_in_sec  5_in_sec      W1     Wh1  \
# 2 2011-03-06 00:00:00  Sunday            0         0  386.96   32.35
# 3 2011-03-06 00:05:00  Sunday            0       500  182.80   47.59
# 4 2011-03-06 00:10:00  Sunday            0      1000  265.95   69.75
# 5 2011-03-06 00:15:00  Sunday            0      1500  277.02   92.83
# 6 2011-03-06 00:20:00  Sunday            0      2000  257.19  114.27
#
#    Frequency
# 2      49.97
# 3      50.00
# 4      50.01
# 5      50.00
# 6      50.00

# %%
Average_min_weekend = sns.lineplot(x='hour_in_sec', y="W1", hue="day", data= make_weekend(Home_1_2011_June_03_to_17))

# %%
Average_min_week = sns.lineplot(x='hour_in_sec', y="W1", hue="day", data= make_week(Home_1_2011_June_03_to_17))

# %%
# Sunday 
sns.lineplot(x='5_in_sec', y="W1", hue="day", 
                      data= Home_1_2011_June_03_to_17[Home_1_2011_June_03_to_17['day']=='Sunday'])

Total_average_min = sns.lineplot(x='5_in_sec', y="W1", data=Home_1_2011_June_03_to_17)

# %%
# Monday  
sns.lineplot(x='5_in_sec', y="W1", hue="day", 
                      data= Home_1_2011_June_03_to_17[Home_1_2011_June_03_to_17['day']=='Monday'])

Total_average_min = sns.lineplot(x='5_in_sec', y="W1", data=Home_1_2011_June_03_to_17)

# %%
# Tuesday  
sns.lineplot(x='5_in_sec', y="W1", hue="day", 
                      data= Home_1_2011_June_03_to_17[Home_1_2011_June_03_to_17['day']=='Tuesday'])

Total_average_min = sns.lineplot(x='5_in_sec', y="W1", data=Home_1_2011_June_03_to_17)

# %%
# Wednesday  
sns.lineplot(x='5_in_sec', y="W1", hue="day", 
                      data= Home_1_2011_June_03_to_17[Home_1_2011_June_03_to_17['day']=='Wednesday'])

Total_average_min = sns.lineplot(x='5_in_sec', y="W1", data=Home_1_2011_June_03_to_17)

# %%
# Thursday  
sns.lineplot(x='5_in_sec', y="W1", hue="day", 
                      data= Home_1_2011_June_03_to_17[Home_1_2011_June_03_to_17['day']=='Thursday'])

Total_average_min = sns.lineplot(x='5_in_sec', y="W1", data=Home_1_2011_June_03_to_17)

# %%
# Friday  
sns.lineplot(x='5_in_sec', y="W1", hue="day", 
                      data= Home_1_2011_June_03_to_17[Home_1_2011_June_03_to_17['day']=='Friday'])

Total_average_min = sns.lineplot(x='5_in_sec', y="W1", data=Home_1_2011_June_03_to_17)

# %%
# Saturday  
sns.lineplot(x='5_in_sec', y="W1", hue="day", 
                      data= Home_1_2011_June_03_to_17[Home_1_2011_June_03_to_17['day']=='Saturday'])

Total_average_min = sns.lineplot(x='5_in_sec', y="W1", data=Home_1_2011_June_03_to_17)
